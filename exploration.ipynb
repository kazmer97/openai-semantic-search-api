# %%
import pandas as pd

# %%
data = pd.read_json("meta_Amazon_Fashion.jsonl", lines=True)

# %%
data
# Out:
#          main_category                                              title  \
# 0       AMAZON FASHION  YUEDGE 5 Pairs Men's Moisture Control Cushione...
# 1       AMAZON FASHION  DouBCQ Women's Palazzo Lounge Wide Leg Casual ...
# 2       AMAZON FASHION  Pastel by Vivienne Honey Vanilla Girls' Trapez...
# 3       AMAZON FASHION                                   Mento Streamtail
# 4       AMAZON FASHION  RONNOX Women's 3-Pairs Bright Colored Calf Com...
# ...                ...                                                ...
# 826103  AMAZON FASHION  Salimdy Women's Fashion New Ruched Waist Class...
# 826104  AMAZON FASHION  Cat Mom Tshirt Trendy Short Sleeve Crewneck Gr...
# 826105  AMAZON FASHION  Nike San Francisco 49ers Hot Quarter Zip S/S P...
# 826106  AMAZON FASHION  Joe's USA Mens 3X-Large Tall Long Sleeve Easy ...
# 826107  AMAZON FASHION  VANGETIMI Gold Choker Necklace Adjustable Dain...
#
#         average_rating  rating_number  \
# 0                  4.6             16
# 1                  4.1              7
# 2                  4.3             11
# 3                  2.0              1
# 4                  4.3           3032
# ...                ...            ...
# 826103             2.0              1
# 826104             5.0              1
# 826105             5.0              1
# 826106             5.0              2
# 826107             5.0              1
#
#                                                  features  \
# 0                                                      []
# 1                      [Drawstring closure, Machine Wash]
# 2                        [Zipper closure, Hand Wash Only]
# 3       [Thermoplastic Rubber sole, High Density Premi...
# 4       [Pull On closure, Size Guide: "S" fits calf 10...
# ...                                                   ...
# 826103                                                 []
# 826104  [Cotton Blend, Material: Mother's day gift cat...
# 826105                   [Zipper closure, Hand Wash Only]
# 826106        [100% Cotton, Button closure, Machine Wash]
# 826107                                                 []
#
#                                               description  price  \
# 0                                                      []    NaN
# 1                                                      []    NaN
# 2                                                      []    NaN
# 3       [Slip on the Women's Mento and you're ready to...  29.81
# 4       [Ronnox Calf Sleeves - Allowing Your Body to P...  17.99
# ...                                                   ...    ...
# 826103                                                 []    NaN
# 826104  [Womens cat shirt casual summer short sleeve c...    NaN
# 826105                                                 []    NaN
# 826106                                                 []    NaN
# 826107                                                 []    NaN
#
#                                                    images  \
# 0       [{'thumb': 'https://m.media-amazon.com/images/...
# 1       [{'thumb': 'https://m.media-amazon.com/images/...
# 2       [{'thumb': 'https://m.media-amazon.com/images/...
# 3       [{'thumb': 'https://m.media-amazon.com/images/...
# 4       [{'thumb': 'https://m.media-amazon.com/images/...
# ...                                                   ...
# 826103  [{'thumb': 'https://m.media-amazon.com/images/...
# 826104  [{'thumb': 'https://m.media-amazon.com/images/...
# 826105  [{'thumb': 'https://m.media-amazon.com/images/...
# 826106  [{'thumb': 'https://m.media-amazon.com/images/...
# 826107  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                                    videos               store  \
# 0                                                      []            GiveGift
# 1                                                      []              DouBCQ
# 2                                                      []  Pastel by Vivienne
# 3                                                      []          Guy Harvey
# 4       [{'title': 'HONEST Review: RONNOX Women's 3-Pa...              RONNOX
# ...                                                   ...                 ...
# 826103                                                 []             Salimdy
# 826104                                                 []             Generic
# 826105                                                 []                Nike
# 826106                                                 []           Joe's USA
# 826107                                                 []           VANGETIMI
#
#        categories                                            details  \
# 0              []  {'Package Dimensions': '10.31 x 8.5 x 1.73 inc...
# 1              []  {'Package Dimensions': '15 x 10.2 x 0.4 inches...
# 2              []  {'Is Discontinued By Manufacturer': 'No', 'Pac...
# 3              []  {'Package Dimensions': '11.22 x 4.72 x 4.33 in...
# 4              []  {'Is Discontinued By Manufacturer': 'No', 'Pac...
# ...           ...                                                ...
# 826103         []  {'Is Discontinued By Manufacturer': 'No', 'Pac...
# 826104         []  {'Package Dimensions': '12.32 x 11.06 x 0.79 i...
# 826105         []  {'Package Dimensions': '12 x 8 x 1 inches', 'I...
# 826106         []  {'Product Dimensions': '6 x 6 x 0.5 inches; 0....
# 826107         []  {'Package Dimensions': '3.54 x 2.76 x 0.39 inc...
#
#        parent_asin  bought_together
# 0       B08BHN9PK5              NaN
# 1       B08R39MRDW              NaN
# 2       B077KJHCJ4              NaN
# 3       B0811M2JG9              NaN
# 4       B07SB2892S              NaN
# ...            ...              ...
# 826103  B078HY8B34              NaN
# 826104  B09V5DB85S              NaN
# 826105  B00NTQ14CK              NaN
# 826106  B00Y8O4N8E              NaN
# 826107  B0895H6NWS              NaN
#
# [826108 rows x 14 columns]

# %%
import psycopg2 as pg

# %%
conn = pg.connect(
    host="localhost",
    port="5432",
    database="vectordb",
    user="postgres",
    password="password99",
)
cur = conn.cursor()
# cur.execute(
#     """
# CREATE EXTENSION IF NOT EXISTS vector;

# CREATE TABLE IF NOT EXISTS embeddings (
#     id serial PRIMARY KEY,
#     content text NOT NULL,
#     embedding vector(1536) NOT NULL
# );

# CREATE INDEX IF NOT EXISTS embeddings_embedding_idx
# ON embeddings USING ivfflat (embedding vector_l2_ops)
# WITH (lists = 100);
# """
# )

cur.execute(
    """
SELECT EXISTS (
        SELECT FROM information_schema.tables 
        WHERE table_schema = 'public'
          AND table_name = 'embeddings'
    );
"""
)
print(cur.fetchone()[0])
conn.commit()
cur.close()
conn.close()
# Out:
# True
